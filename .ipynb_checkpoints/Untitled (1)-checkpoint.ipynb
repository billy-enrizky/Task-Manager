# %%
import requests

# Your Edamam API credentials
app_id = '34340b2c'
app_key = 'aa54ba6e5ea8ffdd204444757a4983d2'

# Specify the dish you want to search for
dish_name = 'YP Burger'

# Make the API request
url = f'https://api.edamam.com/api/food-database/parser'
params = {
    'app_id': app_id,
    'app_key': app_key,
    'ingr': dish_name,
}
response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    # Extract and print the ingredients
    ingredients = data.get('parsed')
    if ingredients:
        for ingredient in ingredients:
            print(ingredient['food']['label'])
else:
    print(f"API request failed with status code {response.status_code}")

# %%
data
# Out:
# {'text': 'YP Burger',
#  'parsed': [],
#  'hints': [{'food': {'foodId': 'food_auepntbalti4kfaw2ub85bvqe2r6',
#     'label': 'Burgers',
#     'nutrients': {'ENERC_KCAL': 132.0,
#      'PROCNT': 22.520000457763672,
#      'FAT': 4.639999866485596,
#      'CHOCDF': 1.3200000524520874,
#      'FIBTG': 0.0},
#     'brand': 'BOULDER BURGER COMPANY',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'WHITE TURKEY; SEA SALT; NATURAL FLAVOR; BLACK PEPPER.',
#     'image': 'https://www.edamam.com/food-img/f08/f08b1f8e5e4061c53d167178dd4d88b2.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_ahrvu7obfgmqbqbhff48caijedve',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 159.0,
#      'PROCNT': 7.079999923706055,
#      'FAT': 6.190000057220459,
#      'CHOCDF': 21.239999771118164,
#      'FIBTG': 5.300000190734863},
#     'brand': 'Meijer, Inc.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'FILTERED WATER; BLACK BEANS; COOKED LONG GRAIN BROWN RICE; EXPELLER PRESSED SUNFLOWER OIL AND/OR CANOLA OIL; CORN; ONION; SOY PROTEIN CONCENTRATE; TOMATO PASTE; POTATO STARCH; SPICE; EVAPORATED CANE SYRUP; GREEN BELL PEPPER; RED BELL PEPPER; MODIFIED VEGETABLE GUM; ONION POWDER; GARLIC POWDER; YEAST EXTRACT; LIME JUICE CONCENTRATE; SEA SALT; NATURAL FLAVOR; PAPRIKA; WHEAT FLOUR; SESAME.'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_b1ujl21b30wo7wanf21uwbe1vohf',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 230.0,
#      'PROCNT': 13.270000457763672,
#      'FAT': 15.930000305175781,
#      'CHOCDF': 8.850000381469727,
#      'FIBTG': 5.300000190734863},
#     'brand': 'Turtle Island Foods, Inc.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'WATER; ORGANIC SOY FLOUR; EXPELLER PRESSED NON-GMO CANOLA OIL; PEA PROTEIN; NON-GMO COCONUT OIL; ORGANIC WHITE VINEGAR; LESS THAN 2% OF SEA SALT; VEGAN NATURAL FLAVOR; BEET JUICE; CITRIC ACID; ORGANIC CARAMEL COLOR; SUNFLOWER OIL; POTASSIUM CHLORIDE; AGAR AGAR; MODIFIED CELLULOSE GUM; GUM ARABIC; XANTHAN GUM.'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_b2o9v6sazh5l0qbr1th82btysgxg',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 182.6625386996904,
#      'PROCNT': 14.241486068111456,
#      'FAT': 8.978328173374614,
#      'CHOCDF': 11.455108359133128,
#      'FIBTG': 0.6191950464396285},
#     'brand': 'Broadway Pizza Restaurant',
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_a2qh5rxba00t70avbkmbvbtt5by2',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 274.5098039215686,
#      'PROCNT': 27.45098039215686,
#      'FAT': 17.64705882352941,
#      'CHOCDF': 0.0,
#      'FIBTG': 0.0},
#     'brand': 'Calypso Cafe',
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_b4lkmzcbd47x86b1d05gsbz7vp2a',
#     'label': 'Burgers',
#     'nutrients': {'ENERC_KCAL': 141.0,
#      'PROCNT': 15.869999885559082,
#      'FAT': 7.940000057220459,
#      'CHOCDF': 0.8799999952316284,
#      'FIBTG': 0.0},
#     'brand': 'BRAVA MEAT CO.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'NATURAL BEEF*; MUSHROOMS; SEASONING (SALT; DEXTROSE; NATURAL FLAVORS; DEHYDRATED ONION; DEHYDRATED GARLIC; SPICES; CONTAINS 2% OR LESS OF: LARD; BEEF FAT; BACON FAT).'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_aizs3ppa1dj03zb84ydclb1oyt7w',
#     'label': 'Burgers',
#     'nutrients': {'ENERC_KCAL': 252.0,
#      'PROCNT': 17.219999313354492,
#      'FAT': 19.8700008392334,
#      'CHOCDF': 0.0,
#      'FIBTG': 0.0},
#     'brand': 'WAHLBURGERS',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BEEF'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bg1wy4bb60u2rwa4kl8yyb588h0s',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 88.0,
#      'PROCNT': 0.0,
#      'FAT': 0.0,
#      'CHOCDF': 23.530000686645508,
#      'FIBTG': 5.900000095367432},
#     'brand': 'Kettle-cooked Crafters, LLC',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'WATER; SUGAR; SALT; TOMATO PASTE; SOY PROTEIN CONCENTRATE; VINEGAR; SPICES; CHIPOTLE PEPPER*; HONEY. CONTAINS 2% OR LESS OF EACH OF THE FOLLOWING: GARLIC*; NATURAL SMOKE FLAVOR WITH OTHER NATURAL FLAVOR; CITRIC ACID; FLAVORINGS; POTASSIUM SORBATE AND SODIUM BENZOATE (PRESERVATIVES); SUCRALOSE.'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon',
#      'label': 'Tablespoon'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_akfxjb5bf8tkv3al68zd6apf7inq',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 260.1626016260162,
#      'PROCNT': 19.10569105691057,
#      'FAT': 13.008130081300813,
#      'CHOCDF': 15.853658536585366,
#      'FIBTG': 1.2195121951219512},
#     'brand': "Dickey's Barbecue Pit",
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_a3k9holaf8359hbtax7zsatpazgm',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 179.69753554039363,
#      'PROCNT': 17.30420712611198,
#      'FAT': 11.97983570269291,
#      'CHOCDF': 0.0,
#      'FIBTG': 0.0},
#     'brand': 'Mooyah',
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_aki88j3afqehwfab6voz2bksv29p',
#     'label': 'Burger',
#     'nutrients': {'ENERC_KCAL': 239.43661971830983,
#      'PROCNT': 15.492957746478872,
#      'FAT': 18.309859154929576,
#      'CHOCDF': 1.408450704225352,
#      'FIBTG': 0.0},
#     'brand': "Tubby's",
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bnmx85pa7s8ivza9sbutwa7plfka',
#     'label': 'Burger Seasoning Mix, Burger',
#     'nutrients': {'ENERC_KCAL': 333.0,
#      'PROCNT': 16.670000076293945,
#      'FAT': 0.0,
#      'CHOCDF': 66.66999816894531},
#     'brand': 'McCormick & Company, Inc.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'ONION; SPICES (INCLUDING BLACK PEPPER AND MUSTARD); GARLIC; SALT; RED BELL PEPPER; SUGAR; CORN MALTODEXTRIN; HYDROLYZED CORN GLUTEN; SOY PROTEIN; AND WHEAT GLUTEN; VINEGAR; NATURAL FLAVOR; AND MOLASSES.'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_teaspoon',
#      'label': 'Teaspoon'}]},
#   {'food': {'foodId': 'food_bebqtr9bkfpp7kbppwzhvad35oo5',
#     'label': 'Aloha Burgers',
#     'nutrients': {'ENERC_KCAL': 172.44380911680943,
#      'PROCNT': 9.234123809659792,
#      'FAT': 10.052068589847753,
#      'CHOCDF': 11.007834988193018,
#      'FIBTG': 0.616582205923923},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'pineapple; teriyaki sauce; ground beef; sweet onion; butter; lettuce; sesame seed; Swiss cheese; bacon'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_bym5417as59vdna84dpwxby1s5q1',
#     'label': 'American Burger',
#     'nutrients': {'ENERC_KCAL': 204.35582066275452,
#      'PROCNT': 10.812834995501824,
#      'FAT': 12.488868800899604,
#      'CHOCDF': 11.931369105330084,
#      'FIBTG': 1.0028425196895927},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'Ground Chuck; Short Rib; Salt; Cheese; Potato Buns; Lettuce; Onion; extra virgin olive oil; garlic; kosher salt; Roma tomatoes'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_atb5prjbwf7pz3a23h3osbbcirbk',
#     'label': 'Aussie Burgers',
#     'nutrients': {'ENERC_KCAL': 160.8612970762428,
#      'PROCNT': 9.77240826737298,
#      'FAT': 9.079510750983793,
#      'CHOCDF': 10.061175190860077,
#      'FIBTG': 1.0003679177286149},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'ground beef; salt; pepper; hamburger buns; lettuce; tomato; beetroot; cheddar cheese; fried eggs; ketchup; mustard'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_b3ru91ubao7g9va5jtx9tbsyfutn',
#     'label': 'Barbecue Burger',
#     'nutrients': {'ENERC_KCAL': 207.67884055804777,
#      'PROCNT': 13.914105505213428,
#      'FAT': 11.74955714766958,
#      'CHOCDF': 11.276908011600048,
#      'FIBTG': 1.0817416558106687},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'ground beef; bread crumbs; Worcestershire sauce; barbecue sauce; English muffins'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_aqe5qn8a8jpu59a476pbeb548r1p',
#     'label': 'Basil Burgers',
#     'nutrients': {'ENERC_KCAL': 250.68571430347703,
#      'PROCNT': 13.827984064495473,
#      'FAT': 16.671839466360836,
#      'CHOCDF': 10.439758749739678,
#      'FIBTG': 0.8770947709175247},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'beef mince; garlic; extra virgin olive oil; salt; black pepper; basil; hamburger buns'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_bsnmrhpagba0yoac57m4rahvrtna',
#     'label': 'Bean Burgers',
#     'nutrients': {'ENERC_KCAL': 160.35415488880966,
#      'PROCNT': 7.445632368807241,
#      'FAT': 6.109869995690095,
#      'CHOCDF': 19.64873462249612,
#      'FIBTG': 4.15031485136296},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'sunflower oil; onion; carrot; canned borlotti beans; beans; breadcrumbs; tomato sauce; burger buns; lettuce'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_b4rlckvahh2whgabxehd9b4govyx',
#     'label': 'Beef Burgers',
#     'nutrients': {'ENERC_KCAL': 184.86445390473534,
#      'PROCNT': 12.330707493104965,
#      'FAT': 11.109293527698561,
#      'CHOCDF': 8.788565330151949,
#      'FIBTG': 0.9140092765552649},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'beef mince; onion; egg; oregano; basil; chilli powder; cumin; masala; coriander; Worcestershire Sauce; tomato sauce; Tabasco sauce; garlic; salt; pepper; breadcrumbs'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_burger',
#      'label': 'Burger'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_buxh9fnbgy33gya3h8ap0bbw3xib',
#     'label': 'Brat Burgers',
#     'nutrients': {'ENERC_KCAL': 167.2321886063087,
#      'PROCNT': 6.259711760801395,
#      'FAT': 10.56509654762393,
#      'CHOCDF': 11.567659708693803,
#      'FIBTG': 0.6373693597787554},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'yeast; buttermilk; ale; water; bread flour; kosher salt; sugar; light brown sugar; vegetable oil; baking soda; heavy whipping cream; American cheese; Jack cheese; lemon juice; ground veal; ground pork; ground nutmeg; white pepper; ginger powder; butter; Buns'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]}],
#  '_links': {'next': {'title': 'Next page',
#    'href': 'https://api.edamam.com/api/food-database/parser?session=40&app_id=34340b2c&app_key=aa54ba6e5ea8ffdd204444757a4983d2&ingr=YP+Burger'}}}

# %%
import openai

# Set your OpenAI API key
api_key = "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"

# Your input prompt to generate a list of ingredients for a food dish
prompt = "List the ingredients for Fish and Chips."

# Make a request to GPT-3
response = openai.Completion.create(
    engine="text-davinci-002",  # Choose the appropriate engine
    prompt=prompt,
    max_tokens=100,  # Adjust as needed
    api_key=api_key
)

# Extract the generated ingredients list from the response
ingredients = response.choices[0].text

# Print the ingredients
print(ingredients)
# Out:
# fish, potatoes, salt, vinegar, ketchup, newspaper

# %%
ingredients = ingredients.split()

# %%
ingredients
# Out:
# ['fish,', 'potatoes,', 'salt,', 'vinegar,', 'ketchup,', 'newspaper']

# %%
import pandas as pd

# %%
df = pd.DataFrame(ingredients)

# %%
df
# Out:
#            0
# 0      fish,
# 1  potatoes,
# 2      salt,
# 3   vinegar,
# 4   ketchup,
# 5  newspaper

# %%
import pytesseract
from PIL import Image

# Load the image
image = Image.open("image.jpg")

# Perform OCR
text = pytesseract.image_to_string(image)

# Print or use the extracted text
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File C:\Anaconda3\envs\MGFD25\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File C:\Anaconda3\envs\MGFD25\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[2], line 8
#       5 image = Image.open("image.jpg")
#       7 # Perform OCR
# ----> 8 text = pytesseract.image_to_string(image)
#      10 # Print or use the extracted text
#      11 print(text)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pytesseract\pytesseract.py:426, in image_to_string.<locals>.<lambda>()
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
#     423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pytesseract\pytesseract.py:288, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     277 with save(image) as (temp_name, input_filename):
#     278     kwargs = {
#     279         'input_filename': input_filename,
#     280         'output_filename_base': temp_name,
#    (...)
#     285         'timeout': timeout,
#     286     }
# --> 288     run_tesseract(**kwargs)
#     289     filename = f"{kwargs['output_filename_base']}{extsep}{extension}"
#     290     with open(filename, 'rb') as output_file:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pytesseract\pytesseract.py:260, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     258         raise
#     259     else:
# --> 260         raise TesseractNotFoundError()
#     262 with timeout_manager(proc, timeout) as error_string:
#     263     if proc.returncode:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in c:\users\suharnom\appdata\roaming\python\python39\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\anaconda3\envs\mgfd25\lib\site-packages (from pytesseract) (22.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\anaconda3\envs\mgfd25\lib\site-packages (from pytesseract) (9.4.0)
# Note: you may need to restart the kernel to use updated packages.
